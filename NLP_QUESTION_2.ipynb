# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
dataset = pd.read_csv('/content/housing.csv')
dataset.head(50).plot.line(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f875f5b4ef0>,
# ...
#       dtype=object)
